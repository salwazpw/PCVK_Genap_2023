# %% [markdown]
# <a href="https://colab.research.google.com/github/salwazpw/PCVK_Genap_2023/blob/main/Week2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive


# Accessing My Google Drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np
img = cv.imread('/content/drive/MyDrive/PCVK/kitten01.jpg')
plt.imshow(img)

# %%
img2 = img
img3 = cv.cvtColor(img, cv.COLOR_BGR2RGB)         #Konversi channel BGR -> RGB
plt.imshow(img3)

# %%
img_gray = cv.imread('/content/drive/MyDrive/PCVK/kitten01.jpg', cv.IMREAD_GRAYSCALE)
plt.imshow(img_gray)

# %%
plt.imshow(img_gray,cmap='gray')

# %%
plt.imshow(img_gray,cmap='magma')

# %%
img4 = cv.resize(cv.cvtColor(img,cv.COLOR_BGR2RGB),(512,1024))
plt.imshow(img4)

# %%
img5 = cv.flip(cv.cvtColor(img, cv.COLOR_BGR2RGB),0)

#Tampilkan plot dengan ukuran canvas yg lebih besar
fig = plt.figure(figsize=(10,10))     #ubah-ubah ukuran (10,10) sesuai kebutuhan
ax = fig.add_subplot(111)
ax.imshow(img5)

# %%
black_img = np.zeros(shape=(512,512,3),dtype=np.int16)
plt.imshow(black_img)

# %%
#Memberikan koordinat titik pt1 dan pt2
cv.rectangle(black_img,pt1=(384,0),pt2=(510,150),color=(0,255,0), thickness = 10)
plt.imshow(black_img)

# %%
cv.rectangle(black_img,pt1=(200,200),pt2=(300,300),color=(0,0,255), thickness = 15)
plt.imshow(black_img)

# %%
#Menambahkan lingkaran
cv.circle(black_img,center=(100,100),radius=50,color=(255,0,0), thickness = 8)
plt.imshow(black_img)

# %%
#Menambahkan lingkaran merah 
cv.circle(black_img,center=(400,400),radius=50,color=(255,0,0), thickness = -1)
plt.imshow(black_img)

# %%
#Menambahkan garis horizontal
cv.line(black_img, pt1=(0,0), pt2=(512,512), color=(255,255,255), thickness = 5)
plt.imshow(black_img)

# %%
#Menambahkan Text
font = cv.FONT_HERSHEY_SIMPLEX
cv.putText(black_img,text='Hello',org=(10,500),fontFace=font,fontScale=4,color=(255,255,0),thickness=2,lineType=cv.LINE_AA)
plt.imshow(black_img)

# %%
black_img2 = np.zeros(shape=(512,512,3), dtype=np.int32)
plt.imshow(black_img2)

# %%
vertices = np.array([[100,300], [200,200], [400,300], [200,400]], dtype=np.int32)
vertices
# Out:
# array([[100, 300],
#        [200, 200],
#        [400, 300],
#        [200, 400]], dtype=int32)

# %%
pts = vertices.reshape((-1,1,2)) #Nilai 2 untuk menunjukkan bahwa tiap titik dibuat 3 channel yg mewakili R,G,B
pts
# Out:
# array([[[100, 300]],
#
#        [[200, 200]],
#
#        [[400, 300]],
#
#        [[200, 400]]], dtype=int32)

# %%
#Menambahkan Polyline
cv.polylines(black_img2,[pts],isClosed=True,color=(255,0,0), thickness = 5)
plt.imshow(black_img2)

# %% [markdown]
# **TUGAS**

# %% [markdown]
# 2.	Tampilkan image

# %%
# RED-BLUE
img_rb = cv.imread('/content/drive/MyDrive/PCVK/kitten01.jpg')
# memisahkan channel blue, green dan red masng-masing disimpan pada variabel b,g,r
b, g, r = cv.split(img)
# atau bisa menggunakan 
# b = img[...,0]  # blue channel
# g = img[...,1]  # green channel
# r = img[...,2]  # red channel

#gabung chanel red dan blue
img_rb = cv.merge([r, b, b])
plt.imshow(img_rb)
plt.show()

# %%
# GREEN-BLUE
img_gb = cv.imread('/content/drive/MyDrive/PCVK/kitten01.jpg')
b, g, r = cv.split(img_gb)
img_gb = cv.merge([g, b, b])
plt.imshow(img_gb)
plt.show()

# %% [markdown]
# 3. Tampilkan image baris ke 20-115, kolom 25-120

# %%
img = cv.imread('/content/drive/MyDrive/PCVK/kitten01.jpg')
plt.imshow(img[20:115 , 25:120])

# %% [markdown]
# 4.	Tampilkan image baris ke 5-30, semua kolom, channel Red saja

# %%
img = cv.imread('/content/drive/MyDrive/PCVK/kitten01.jpg')
b, g, r = cv.split(img)
img = cv.merge([r, r, r])
plt.imshow(img[5:30], cmap='gray')

# %% [markdown]
# 5.	Buat 5 kotak berbagai ukuran dan warna yang berbeda dalam satu image. disarankan menggunakan bilangan acak/random!

# %%
img = cv.imread('/content/drive/MyDrive/PCVK/kitten01.jpg')
img = cv.cvtColor(img,cv.COLOR_BGR2RGB)

cv.rectangle(img, pt1=(354,0), pt2=(40,170), color=(0,255,255), thickness=10)
cv.rectangle(img, pt1=(300,200), pt2=(510,150), color=(0,255,0), thickness=10)
cv.rectangle(img, pt1=(450,500), pt2=(300,200), color=(255,255,0), thickness=10)
cv.rectangle(img, pt1=(200,450), pt2=(600,550), color=(255,0,0), thickness=10)
cv.rectangle(img, pt1=(560,100), pt2=(400,600), color=(0,0,255), thickness=10)

plt.imshow(img)

# %% [markdown]
# 6.	Tampilkan image dengan posisi terbalik!

# %%
img = cv.imread('/content/drive/MyDrive/PCVK/kitten01.jpg')
img = cv.flip(cv.cvtColor(img, cv.COLOR_BGR2RGB),0)
plt.imshow(img5)

# %% [markdown]
# 7.	Buat rectangle dan circle pada bagian wajah dari image foto anda saat beraktifitas (bukan pasfoto).

# %%
img7 = cv.imread('/content/drive/MyDrive/PCVK/pic.JPG')
img_task7 = cv.cvtColor(img7, cv.COLOR_BGR2RGB)
cv.rectangle(img_task7, pt1=(480,300), pt2 =(650,100), color = (255,255,0), thickness = 10)
cv.circle(img_task7, center = (570,200) , radius = 80, color = (0,255,0), thickness = 10)
plt.imshow(img_task7)

# %% [markdown]
# 8.	Buat rectangle pada bagian sudut bawah kiri channel B pada color space RGB dari citra kitten/ lena/ mandrill/ male/ female/ couple/ sailboat/ peppers!

# %%
img8 = cv.imread('/content/drive/MyDrive/PCVK/kitten01.jpg')
img_task8 = cv.cvtColor(img8, cv.COLOR_BGR2RGB)
img_task8[450:,:200,0] = 0
img_task8[450:,:200,1] = 0
plt.imshow(img_task8)

# %% [markdown]
# 9.	Lengkapi tulisan nama file pada file citra dari soal no.8. gunakan font, ukuran font, dan warna font yang sesuai keinginan anda.

# %%
font  = cv.FONT_HERSHEY_TRIPLEX
img_task9 = img_task8.copy()
cv.putText(img_task9, text="Hello! I'm a kitten", org=(500,100), fontFace=font, fontScale=2, color =(0,0,0),thickness = 5, lineType = cv.LINE_AA)
plt.imshow(img_task9)
